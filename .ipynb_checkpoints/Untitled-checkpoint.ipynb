# %%
from pymongo import MongoClient
import dns

# %%
client = MongoClient("mongodb+srv://dbUser:resumepassword@resumescanner.klqbp.mongodb.net/resumes?retryWrites=true&w=majority")
db = client.test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ccbde4968556> in <module>
# ----> 1 client = pymongo.MongoClient("mongodb+srv://dbUser:resumepassword@resumescanner.klqbp.mongodb.net/resumes?retryWrites=true&w=majority")
#       2 db = client.test
#
# NameError: name 'pymongo' is not defined
